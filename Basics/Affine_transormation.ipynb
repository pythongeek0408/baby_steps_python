# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
v = np.array([3,1])
print(v)
# Out:
# [3 1]

# %%
def plot_vectors(vectors, colors): #
    """
    Plot one or more vectors in a 2D plane, specifying a color for each. 

    Arguments
    ---------
    vectors: list of lists or of arrays
        Coordinates of the vectors to plot. For example, [[1, 3], [2, 2]] 
        contains two vectors to plot, [1, 3] and [2, 2].
    colors: list
        Colors of the vectors. For instance: ['red', 'blue'] will display the
        first vector in red and the second in blue.
        
    Example
    -------
    plot_vectors([[1, 3], [2, 2]], ['red', 'blue'])
    plt.xlim(-1, 4)
    plt.ylim(-1, 4)
    """
    plt.figure()
    plt.axvline(x=0, color='lightgray')
    plt.axhline(y=0, color='lightgray')

    for i in range(len(vectors)):
        x = np.concatenate([[0,0],vectors[i]])
        plt.quiver([x[0]], [x[1]], [x[2]], [x[3]],
                   angles='xy', scale_units='xy', scale=1, color=colors[i],)

# %%
plot_vectors([v],['lightblue'])
plt.xlim(-1,5)
_ = plt.ylim(-1,5)

# %%
I = np.array([[1,0],[0,1]])
print(I)
# Out:
# [[1 0]
#  [0 1]]

# %%
Iv = torch.matmul(torch.from_numpy(v),torch.from_numpy(I))
print(Iv)
# Out:
# tensor([3, 1])

# %%
torch.from_numpy(v)==Iv
# Out:
# tensor([True, True])

# %%
plot_vectors([Iv],['darkblue']) # Applying Identity matrix to vector does not change it
plt.xlim(-1,5)
_ = plt.ylim(-1,5)

# %%
E = torch.tensor([[1,0],[0,-1]])
print(E)
# Out:
# tensor([[ 1,  0],
#         [ 0, -1]])

# %%
Ev = torch.matmul(torch.from_numpy(v),E) # Flips the vector over X axis
plot_vectors([v,Ev],['lightblue','blue']) 
plt.xlim(-1,5)
_ = plt.ylim(-3,3)

# %%
F = torch.tensor([[-1,0],[0,1]])
print(F)
Fv = torch.matmul(torch.from_numpy(v),F) # Flips the vector over y axis
plot_vectors([v,Fv],['lightblue','blue']) 
plt.xlim(-4,5)
_ = plt.ylim(-4,3)
# Out:
# tensor([[-1,  0],
#         [ 0,  1]])

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
R = torch.tensor([[0,-1],[1,0]])
R
# Out:
# tensor([[ 0, -1],
#         [ 1,  0]])

# %%
def plot_vectors(vectors, colors): #
    """
    Plot one or more vectors in a 2D plane, specifying a color for each. 

    Arguments
    ---------
    vectors: list of lists or of arrays
        Coordinates of the vectors to plot. For example, [[1, 3], [2, 2]] 
        contains two vectors to plot, [1, 3] and [2, 2].
    colors: list
        Colors of the vectors. For instance: ['red', 'blue'] will display the
        first vector in red and the second in blue.
        
    Example
    -------
    plot_vectors([[1, 3], [2, 2]], ['red', 'blue'])
    plt.xlim(-1, 4)
    plt.ylim(-1, 4)
    """
    plt.figure()
    plt.axvline(x=0, color='lightgray')
    plt.axhline(y=0, color='lightgray')

    for i in range(len(vectors)):
        x = np.concatenate([[0,0],vectors[i]])
        plt.quiver([x[0]], [x[1]], [x[2]], [x[3]],
                   angles='xy', scale_units='xy', scale=1, color=colors[i],)

# %%
v = np.array([3,1])
Rv = torch.matmul(torch.from_numpy(v),R)
print(Rv)
plot_vectors([v,Rv],['lightblue','blue']) 
plt.xlim(-4,5)
_ = plt.ylim(-4,3)
# Out:
# tensor([ 1, -3])

# %%
A = torch.tensor([[-1,4],[2,-2]])
print(A)
# Out:
# tensor([[-1,  4],
#         [ 2, -2]])

# %%
Av = torch.matmul(A,torch.from_numpy(v))
print(Av)
plot_vectors([v,Av],['lightblue','blue']) 
plt.xlim(-1,5)
_ = plt.ylim(-1,5)
# Out:
# tensor([1, 4])

# %%
v1 = torch.tensor([[3,1]])
v2 = torch.tensor([[2,1]])
v3 = torch.tensor([[-3,-1]])
v4 = torch.tensor([[-1,1]])

V = torch.cat((v1.T,v2.T,v3.T,v4.T),1) # V made of 4 vectors 
V
# Out:
# tensor([[ 3,  2, -3, -1],
#         [ 1,  1, -1,  1]])

# %%
AV = torch.matmul(A,V)
print(v1.reshape([2]),AV[:,0])
# Out:
# tensor([3, 1]) tensor([1, 4])

# %%
plot_vectors([v1.reshape([2]),v2.reshape([2]),v3.reshape([2]),v4.reshape([2]),AV[:,0],AV[:,1],AV[:,2],AV[:,3]],['lightblue','lightgreen','lightgrey','red','blue','green','grey','orange']) 
plt.xlim(-4,6)
_ = plt.ylim(-5,6)
